# %% [markdown]
# # 1. Semantic Segmentation for Self Driving Cars

# %% [markdown]
# The goal of this model is to be able to classify each pixel of each object seen in an image or video feed on a self driving vehicle. It is useful in helping cars identify objects around them which allows them to be 'aware' of their sorroundings.
#
# The model was trained on the Mapillary Research Dataset, which contains 18000 training images, 2000 validation images, and 5000 testing images. This dataset contains a variety of images of road driving conditions from around the world, which can be used to train neural networks for computer vision in self driving cars.
#
# The dataset also contains labels (masks) for each image which have each of their pixels labelled individually as a unique class, based on the type of object they are a part of in the image. We will be using this data to train our neural network.
#
# To obtain the dataset, you can download it from the Mapillary Dataset website after registering.
#
# It can be found at https://www.mapillary.com/dataset/

# %% [markdown]
# **Note:** All the function definitions used in this notebook can be found in the semantic_segmentation.py file

# %% [markdown]
# #### Neural Network

# %% [markdown]
# The Neural Network we use for our purposes uses a U-net architecture. This was originally designed to isolate various body tissues in medical imaging. It gets its name from the shape of its architecture which is shown below.
#
# <img src="nb_images/Unet.png">
#
# Image from: https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png
# (Please note that the tensor shapes shown in the above image are different from the ones we use in our model)
#
#
# The Unet contains a series of convolutions and pooling layers, with a few 'skip connections that connect directly from the encoding stages to the corresponding decoding stages.

# %% [markdown]
# Lets start with importing all the necessary libraries.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
import tensorflow as tf
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Training this model can take a long time (many hours) so make sure you are using the GPU version of tensorflow to speed it up as much as possible. Let's verify that we have a GPU available.

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Hyperparameters

# %% [markdown]
# We set the hyperparameters for the model here.

# %%
img_width = 256
img_height = 256
batch_size = 5
num_epochs = 20
seed = 42

# %% [markdown]
# ## Image Preprocessing

# %% [markdown]
# The Mapillary Dataset provides very high resolution images (4K) that can be used for professional and research applications, but can also be computationally expensive. For our purposes we resize the images to a 256 x 256 resolution to reduce the computational cost. (It still takes a really long time to train).

# %% [markdown]
# You can use the Image Preprocessing notebook to independently preprocess the images or run the following cell to do it here and return the path to the dataset. To have more control over the number of images in the training, validation and testing sets, use the notebook version.

# %%
# from image_preprocessor import resize_images
# DATA_DIRECTORY = resize_images(MAPILLARY_DATASET, img_size = (256, 256), num_images = 'all')

# %% [markdown]
# We set the locations of the image directories. MAPILLARY_DATASET is the path to the original folder. DATA_DIRECTORY should the the folder you have inside after processing the images using the Image Processor notebook or function.

# %%
MAPILLARY_DATASET = '/home/anupjsebastian/mapillary_dataset/'
DATA_DIRECTORY = '/home/anupjsebastian/mapillary_dataset/resized_256'

# %% [markdown]
# Let's import a function to read the images into tensorflow and then preview them.

# %%
from semantic_segmentation import read_images

# %%
train_image_tensors, train_label_tensors , num_train_images= read_images(DATA_DIRECTORY, 'training', masks = True)
val_image_tensors, val_label_tensors, num_val_images = read_images(DATA_DIRECTORY, 'validation', masks = True)
test_image_tensors, num_test_images = read_images(DATA_DIRECTORY, 'testing', masks = False)
# Out:
# 5000 image files found in training/images folder.
# 5000 mask files found in training/labels folder.
# 300 image files found in validation/images folder.
# 300 mask files found in validation/labels folder.
# 500 image files found in testing/images folder.

# %% [markdown]
# ## Visualization

# %% [markdown]
# Let's now preview some of the images and their corresponding labels.

# %%
from semantic_segmentation import show_images_and_labels

# %% [markdown]
# Starting with the training set

# %%
## Training Images
show_images_and_labels(train_image_tensors, train_label_tensors, num_images_to_show= 2)

# %% [markdown]
# Then the validation set

# %%
## Validation Images
show_images_and_labels(val_image_tensors, val_label_tensors, num_images_to_show= 2)

# %% [markdown]
# And finally the test set

# %%
#Test Images
show_images_and_labels(test_image_tensors, num_images_to_show= 2, masks = False)

# %% [markdown]
# ## Image Information

# %% [markdown]
# The creators of the dataset also provide a config file with information about the various classes in the labels. For our purposes we need to obtain the name of each of the classes and also the RGB color value for the corresponding labels. It should already be there in the same folder where the images are saved.
#
# Let's now read this information from the file

# %%
config = os.path.join(MAPILLARY_DATASET, 'config.json')

# read in config file
with open(config) as config_file:
    config = json.load(config_file)
# in this example we are only interested in the labels
labels = config['labels']

# %%
num_categories = len(labels)

# %%
labels[0]
# Out:
# {'color': [165, 42, 42],
#  'instances': True,
#  'readable': 'Bird',
#  'name': 'animal--bird',
#  'evaluate': True}

# %%
label_names = [label['readable'] for label in labels]
label_colors = [label['color'] for label in labels]

# %% [markdown]
# ## Mapping Label and Color Codes

# %% [markdown]
# We will now create conversion dictionaries that can convert back and forth the label names, and label RGB values into numerical codes. We will one hot encode each category of the label into a different layer in the tensor, so this will be useful for that

# %%
id_to_name = {ID:name for ID, name in enumerate(label_names)}
name_to_id = {name:ID for ID, name in enumerate(label_names)}

# %%
id_to_color = {ID:tuple(color) for ID, color in enumerate(label_colors)}
color_to_id = {tuple(color):ID for ID, color in enumerate(label_colors)}

# %% [markdown]
# Now let's define functions to one hot encode the RGB image, and to convert it back as well.

# %% [markdown]
# ## Input Pipeline

# %% [markdown]
# Since we have a lot of data, lets create an input pipeline that can efficiently load and process the images for training.

# %%
# Normalizing only frame images, since masks contain label info
data_gen_args = dict(rescale=1./255)
mask_gen_args = dict()

train_frames_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**mask_gen_args)
val_frames_datagen = ImageDataGenerator(**data_gen_args)
val_masks_datagen = ImageDataGenerator(**mask_gen_args)

# %% [markdown]
# Let's import a defined Data Generator to efficiently load batches of images into the network for training

# %%
from semantic_segmentation import DataGenerator

# %% [markdown]
# ## Model Definition

# %% [markdown]
# Finally let's import the network architecture oand then create an instance of it.
#
#
# To change the architecture you can modify the *semantic_segmentation.py* file. You could modify (increase) the number of downblocks, upblocks and bottleneck stages if you decide to use larger images.

# %%
from semantic_segmentation import unet

# %%
model = unet(n_filters = num_categories)
# Out:
# Input Shape: Tensor("input_1:0", shape=(None, 256, 256, 3), dtype=float32)

# %% [markdown]
# Now let's import some useful metrics that can be helpful to train our model.

# %%
from semantic_segmentation import dice_coef

# %% [markdown]
# Let's compile the model and get a summary of its architecture.

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=[dice_coef,'accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 66) 1848        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 66) 264         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 66) 39270       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 66) 264         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 66) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 132 78540       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 132 528         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 132 156948      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 132 528         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 132)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 264)  313896      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 264)  1056        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 264)  627528      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 264)  1056        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 264)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 528)  1255056     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 528)  2112        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 528)  2509584     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 528)  2112        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 528)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1056) 5019168     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1056) 4224        conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1056) 10037280    batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1056) 4224        conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1056) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1584) 0           up_sampling2d[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 528)  7527696     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 528)  2112        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 528)  2509584     batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 528)  2112        conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 528)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 792)  0           up_sampling2d_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 264)  1882056     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 264)  1056        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 264)  627528      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 264)  1056        conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 264 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 396 0           up_sampling2d_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 132 470580      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 132 528         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 132 156948      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 132 528         conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 132 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 198 0           up_sampling2d_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 66) 117678      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 66) 264         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 66) 39270       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 66) 264         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 66) 4422        batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 33,399,168
# Trainable params: 33,387,024
# Non-trainable params: 12,144
# __________________________________________________________________________________________________

# %% [markdown]
# ## Pretrained Weights

# %% [markdown]
# As the model takes a long time to train, you could load pretrained weights for the model by running the following cell. The model was trained to 91% training and 85% validation accuracy on the complete Mapillary dataset. You could also optionally run the next cell to run a cycle of validation on the current dataset you are using and obtain some useful metrics.

# %%
# model.load_weights("unet_weights/mapillary_full_dataset_weights.h5")

# %%
# model.evaluate(DataGenerator(DATA_DIRECTORY, 'validation', val_frames_datagen, val_masks_datagen))

# %% [markdown]
# ## Callbacks

# %% [markdown]
# Let's setup some callbacks to run while the model trains. We use Tensorboard to log all the training information, use ModelCheckpoint to create checkpoints as we train our model so we do not lose progress if the model gets interrupted for any reason, and finally EarlyStopping to stop our model early if it starts to overfit or if it stop improving.

# %%
tensorboard = TensorBoard(log_dir='logs', write_graph=True)
checkpoints = ModelCheckpoint(mode='max', filepath='checkpoints/mapillary_model_checkpoint.h5', monitor='accuracy', save_best_only='True', save_weights_only='True', verbose=1)
earlystop = EarlyStopping(mode='max', monitor='val_accuracy', patience=4, verbose=1)
callbacks = [tensorboard, checkpoints, earlystop]

# %% [markdown]
# Let's do a quick calculation for the number of training and validation steps required. This is optional and the model can calculate automatically if not provided, but it can be changed for finer control.

# %%
train_steps = num_train_images//batch_size
val_steps = num_val_images//batch_size

# %% [markdown]
# ## Tensorboard

# %% [markdown]
# We can monitor our progress using Tensorboard within the notebook by running the following cell.
#
# **Note:** Tensorboard is not visible on GitHub.

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-591d144ed41c51e8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-591d144ed41c51e8");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Training

# %% [markdown]
# Finally let's train our model, and save its final weights.

# %%
# Train model
result = model.fit(DataGenerator(DATA_DIRECTORY, 'training', train_frames_datagen, train_masks_datagen, id_to_color), steps_per_epoch = train_steps,
                validation_data = DataGenerator(DATA_DIRECTORY, 'validation', val_frames_datagen, val_masks_datagen, id_to_color), 
                validation_steps = val_steps, epochs = num_epochs, callbacks = callbacks)
# Out:
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Found 300 images belonging to 1 classes.
# Found 300 images belonging to 1 classes.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1000 steps, validate for 60 steps
# Epoch 1/20
#  999/1000 [============================>.] - ETA: 1s - loss: 1.3265 - dice_coef: 0.6924 - accuracy: 0.6649
# Epoch 00001: accuracy improved from -inf to 0.66485, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1231s 1s/step - loss: 1.3265 - dice_coef: 0.6924 - accuracy: 0.6649 - val_loss: 1.1260 - val_dice_coef: 0.7531 - val_accuracy: 0.7144
# Epoch 2/20
#  999/1000 [============================>.] - ETA: 1s - loss: 1.0640 - dice_coef: 0.7548 - accuracy: 0.7196
# Epoch 00002: accuracy improved from 0.66485 to 0.71961, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1223s 1s/step - loss: 1.0639 - dice_coef: 0.7548 - accuracy: 0.7196 - val_loss: 1.0432 - val_dice_coef: 0.7651 - val_accuracy: 0.7266
# Epoch 3/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.9795 - dice_coef: 0.7767 - accuracy: 0.7409
# Epoch 00003: accuracy improved from 0.71961 to 0.74101, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1222s 1s/step - loss: 0.9791 - dice_coef: 0.7768 - accuracy: 0.7410 - val_loss: 0.9502 - val_dice_coef: 0.7884 - val_accuracy: 0.7470
# Epoch 4/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.9085 - dice_coef: 0.7936 - accuracy: 0.7580
# Epoch 00004: accuracy improved from 0.74101 to 0.75799, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1223s 1s/step - loss: 0.9083 - dice_coef: 0.7936 - accuracy: 0.7580 - val_loss: 0.8985 - val_dice_coef: 0.7991 - val_accuracy: 0.7588
# Epoch 5/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.8576 - dice_coef: 0.8054 - accuracy: 0.7700
# Epoch 00005: accuracy improved from 0.75799 to 0.76988, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1243s 1s/step - loss: 0.8580 - dice_coef: 0.8053 - accuracy: 0.7699 - val_loss: 0.8383 - val_dice_coef: 0.8040 - val_accuracy: 0.7682
# Epoch 6/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.8149 - dice_coef: 0.8151 - accuracy: 0.7791
# Epoch 00006: accuracy improved from 0.76988 to 0.77905, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1287s 1s/step - loss: 0.8150 - dice_coef: 0.8151 - accuracy: 0.7791 - val_loss: 0.9315 - val_dice_coef: 0.7894 - val_accuracy: 0.7437
# Epoch 7/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.7800 - dice_coef: 0.8232 - accuracy: 0.7880
# Epoch 00007: accuracy improved from 0.77905 to 0.78807, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1248s 1s/step - loss: 0.7799 - dice_coef: 0.8233 - accuracy: 0.7881 - val_loss: 0.8122 - val_dice_coef: 0.8166 - val_accuracy: 0.7781
# Epoch 8/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.7483 - dice_coef: 0.8302 - accuracy: 0.7948
# Epoch 00008: accuracy improved from 0.78807 to 0.79485, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1257s 1s/step - loss: 0.7482 - dice_coef: 0.8302 - accuracy: 0.7949 - val_loss: 0.7536 - val_dice_coef: 0.8259 - val_accuracy: 0.7876
# Epoch 9/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.7169 - dice_coef: 0.8375 - accuracy: 0.8030
# Epoch 00009: accuracy improved from 0.79485 to 0.80297, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1227s 1s/step - loss: 0.7171 - dice_coef: 0.8374 - accuracy: 0.8030 - val_loss: 0.7216 - val_dice_coef: 0.8323 - val_accuracy: 0.7997
# Epoch 10/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.6902 - dice_coef: 0.8433 - accuracy: 0.8088
# Epoch 00010: accuracy improved from 0.80297 to 0.80884, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1311s 1s/step - loss: 0.6901 - dice_coef: 0.8433 - accuracy: 0.8088 - val_loss: 0.7201 - val_dice_coef: 0.8344 - val_accuracy: 0.8007
# Epoch 11/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.6630 - dice_coef: 0.8494 - accuracy: 0.8156
# Epoch 00011: accuracy improved from 0.80884 to 0.81560, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1290s 1s/step - loss: 0.6628 - dice_coef: 0.8495 - accuracy: 0.8156 - val_loss: 0.7363 - val_dice_coef: 0.8280 - val_accuracy: 0.7941
# Epoch 12/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.6386 - dice_coef: 0.8546 - accuracy: 0.8214
# Epoch 00012: accuracy improved from 0.81560 to 0.82135, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1275s 1s/step - loss: 0.6385 - dice_coef: 0.8546 - accuracy: 0.8214 - val_loss: 0.6760 - val_dice_coef: 0.8472 - val_accuracy: 0.8092
# Epoch 13/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.6140 - dice_coef: 0.8601 - accuracy: 0.8274
# Epoch 00013: accuracy improved from 0.82135 to 0.82743, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1222s 1s/step - loss: 0.6139 - dice_coef: 0.8601 - accuracy: 0.8274 - val_loss: 0.7178 - val_dice_coef: 0.8379 - val_accuracy: 0.7978
# Epoch 14/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.5899 - dice_coef: 0.8656 - accuracy: 0.8337
# Epoch 00014: accuracy improved from 0.82743 to 0.83373, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1222s 1s/step - loss: 0.5899 - dice_coef: 0.8656 - accuracy: 0.8337 - val_loss: 0.7494 - val_dice_coef: 0.8326 - val_accuracy: 0.7935
# Epoch 15/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.5693 - dice_coef: 0.8701 - accuracy: 0.8382
# Epoch 00015: accuracy improved from 0.83373 to 0.83822, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1222s 1s/step - loss: 0.5693 - dice_coef: 0.8701 - accuracy: 0.8382 - val_loss: 0.6713 - val_dice_coef: 0.8463 - val_accuracy: 0.8107
# Epoch 16/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.5456 - dice_coef: 0.8753 - accuracy: 0.8444
# Epoch 00016: accuracy improved from 0.83822 to 0.84440, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1222s 1s/step - loss: 0.5455 - dice_coef: 0.8754 - accuracy: 0.8444 - val_loss: 0.6495 - val_dice_coef: 0.8502 - val_accuracy: 0.8160
# Epoch 17/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.5224 - dice_coef: 0.8804 - accuracy: 0.8499
# Epoch 00017: accuracy improved from 0.84440 to 0.84995, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1221s 1s/step - loss: 0.5223 - dice_coef: 0.8805 - accuracy: 0.8499 - val_loss: 0.7371 - val_dice_coef: 0.8322 - val_accuracy: 0.7957
# Epoch 18/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.4992 - dice_coef: 0.8854 - accuracy: 0.8556
# Epoch 00018: accuracy improved from 0.84995 to 0.85561, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1221s 1s/step - loss: 0.4991 - dice_coef: 0.8854 - accuracy: 0.8556 - val_loss: 0.6630 - val_dice_coef: 0.8528 - val_accuracy: 0.8175
# Epoch 19/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.4771 - dice_coef: 0.8904 - accuracy: 0.8616
# Epoch 00019: accuracy improved from 0.85561 to 0.86154, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1221s 1s/step - loss: 0.4771 - dice_coef: 0.8904 - accuracy: 0.8615 - val_loss: 0.6521 - val_dice_coef: 0.8541 - val_accuracy: 0.8182
# Epoch 20/20
#  999/1000 [============================>.] - ETA: 1s - loss: 0.4509 - dice_coef: 0.8962 - accuracy: 0.8682
# Epoch 00020: accuracy improved from 0.86154 to 0.86818, saving model to checkpoints/mapillary_model_checkpoint.h5
# 1000/1000 [==============================] - 1220s 1s/step - loss: 0.4509 - dice_coef: 0.8962 - accuracy: 0.8682 - val_loss: 0.6717 - val_dice_coef: 0.8570 - val_accuracy: 0.8236

# %%
model.save_weights("mapillary_model_final_weights.h5", overwrite=True)

# %% [markdown]
# ## Predictions

# %% [markdown]
# Finally lets use our model to make a few predictions, from the test set and the training set, and visualize the results

# %%
train_generator = DataGenerator(DATA_DIRECTORY, 'training', train_frames_datagen, train_masks_datagen, id_to_color)
test_generator = DataGenerator(DATA_DIRECTORY, 'validation', val_frames_datagen, val_masks_datagen, id_to_color)

# %% [markdown]
# Let's import a function to quickly make predictions, process our output and plot the results.

# %%
from semantic_segmentation import display_predictions

# %% [markdown]
# #### Training Set

# %% [markdown]
# Note: you can rerun the cell below multiple times to show the next batch of images.

# %%
display_predictions(train_generator, id_to_color, model)
# Out:
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.

# %% [markdown]
# #### Validation Set

# %%
display_predictions(test_generator, id_to_color, model)
# Out:
# Found 300 images belonging to 1 classes.
# Found 300 images belonging to 1 classes.

# %% [markdown]
# That looks pretty good. It's not perfect but still does a decent job. This was trained only for 20 epochs on a small subset of the data. It only reaches 86% training and 83% validation accuracy. More training and more data improves performance.
#
# I have included some weights where the model was trained on Google Colab on the full dataset where it reached 91% training accuracy and 85% validation accuracy. You could import those weights to the model if you want to see better performance.
#
# We can now try and add object detection to our model in the next notebook.
